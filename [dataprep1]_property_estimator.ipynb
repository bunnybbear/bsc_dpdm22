# %% [markdown]
# <a href="https://colab.research.google.com/github/bunnybbear/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/Data Mining')

# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/Data Mining

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %% [markdown]
# ##บ้านเดี่ยว

# %%
open_dataH = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน update.xlsx',sheet_name=0)
open_dataH.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     2890000            2500000.0
# 1                        มั่นใจ     2890000            2700000.0
# 2                        มั่นใจ     2600000            2200000.0
# 3                        มั่นใจ     2600000            2400000.0
# 4                        มั่นใจ     6050000            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %%
open_dataH.shape
# Out:
# (190, 14)

# %%
all_P = set(list(open_dataH['ID ผู้ประเมิน']))
all_P
# Out:
# {1, 2}

# %% [markdown]
# ###พิจารณาผู้ประเมินคนที่ 1

# %%
dataH_P1 = open_dataH[open_dataH['ID ผู้ประเมิน']==1]
dataH_P1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataHP1 = dataH_P1[['ID ผู้ประเมิน','ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataHP1.head()
# Out:
#    ID ผู้ประเมิน  ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1   2700000.0                        มั่นใจ
# 2              1   2600000.0                        มั่นใจ
# 4              1   5900000.0                        มั่นใจ
# 6              1   4400000.0                        มั่นใจ
# 8              1   2750000.0                        มั่นใจ
#
#    ประเมินราคาซื้อ-ขาย                      ให้คะแนนทรัพย์
# 0            2500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 2            2200000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4            5000000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 6            3500000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 8            2500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataHP1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count          100.0  1.000000e+02         1.000000e+02
# mean             1.0  4.316360e+06         3.938500e+06
# std              0.0  2.865391e+06         2.368553e+06
# min              1.0  3.900000e+05         6.000000e+05
# 25%              1.0  2.892750e+06         2.775000e+06
# 50%              1.0  3.962000e+06         3.600000e+06
# 75%              1.0  5.000000e+06         4.500000e+06
# max              1.0  2.094900e+07         1.600000e+07

# %%
dataHP1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
dataHP1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ###พิจารณาผู้ประเมินคนที่ 2

# %%
dataH_P2 = open_dataH[open_dataH['ID ผู้ประเมิน']==2]
dataH_P2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataHP2 = dataH_P2[['ID ผู้ประเมิน','ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataHP2.head()
# Out:
#    ID ผู้ประเมิน  ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 1              2   2700000.0                        มั่นใจ
# 3              2   2600000.0                        มั่นใจ
# 5              2   5900000.0                        มั่นใจ
# 7              2   4400000.0                        มั่นใจ
# 9              2   2750000.0                        มั่นใจ
#
#    ประเมินราคาซื้อ-ขาย                     ให้คะแนนทรัพย์
# 1            2700000.0   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3            2400000.0  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 5            9000000.0  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน
# 7            3700000.0  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 9            2500000.0  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataHP2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count           90.0  9.000000e+01         8.900000e+01
# mean             2.0  4.240733e+06         4.153258e+06
# std              0.0  2.714815e+06         2.386901e+06
# min              2.0  3.900000e+05         9.900000e+05
# 25%              2.0  2.860000e+06         2.600000e+06
# 50%              2.0  4.000000e+06         3.900000e+06
# 75%              2.0  5.000000e+06         4.900000e+06
# max              2.0  2.094900e+07         1.700000e+07

# %%
dataHP2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
dataHP2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##ที่ดิน

# %%
open_dataL = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน update.xlsx',sheet_name=1)
open_dataL.head()
# Out:
#    ID ผู้ประเมิน                               post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1              2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2              4  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3              1  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4              2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     2800000            1800000.0
# 1                        มั่นใจ     2800000            2000000.0
# 2                        มั่นใจ     2800000            2200000.0
# 3                        มั่นใจ    14900000            8000000.0
# 4                        มั่นใจ    14900000           12000000.0
#
#             ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                             8,000-25,000                        NaN
# ...

# %%
open_dataL.shape
# Out:
# (210, 13)

# %% [markdown]
# ###พิจารณาผู้ประเมินคนที่ 1

# %%
dataL_P1 = open_dataL[open_dataL['ID ผู้ประเมิน']==1]
dataL_P1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6                1   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9                1   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12               1   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 201              1  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 203              1  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataLP1 = dataL_P1[['ID ผู้ประเมิน','ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataLP1.head()
# Out:
#     ID ผู้ประเมิน  ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 0               1     2800000                        มั่นใจ
# 3               1    14900000                        มั่นใจ
# 6               1    90000000                        มั่นใจ
# 9               1    65000000                        มั่นใจ
# 12              1     3000000                        มั่นใจ
#
#     ประเมินราคาซื้อ-ขาย                      ให้คะแนนทรัพย์
# 0             1800000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 3             8000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 6            18000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 9            35000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 12            2200000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataLP1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count          100.0  1.000000e+02         1.000000e+02
# mean             1.0  1.644375e+07         9.069000e+06
# std              0.0  4.202164e+07         2.322360e+07
# min              1.0  6.500000e+05         5.000000e+05
# 25%              1.0  1.900000e+06         1.675000e+06
# 50%              1.0  3.999500e+06         3.175000e+06
# 75%              1.0  1.207500e+07         1.000000e+07
# max              1.0  2.860000e+08         2.220000e+08

# %%
dataLP1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
dataLP1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    55
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     45
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ###พิจารณาผู้ประเมินคนที่ 2

# %%
dataL_P2 = open_dataL[open_dataL['ID ผู้ประเมิน']==2]
dataL_P2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataLP2 = dataL_P2[['ID ผู้ประเมิน','ราคาทรัพย์','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataLP2.head()
# Out:
#     ID ผู้ประเมิน  ราคาทรัพย์ ความมั่นใจในการเมินราคาทรัพย์  \
# 1               2     2800000                        มั่นใจ
# 4               2    14900000                        มั่นใจ
# 7               2    90000000                        มั่นใจ
# 10              2    65000000                        มั่นใจ
# 13              2     3000000                        มั่นใจ
#
#     ประเมินราคาซื้อ-ขาย                      ให้คะแนนทรัพย์
# 1             2000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4            12000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 7            70000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 10           60000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 13            2500000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataLP2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# count          100.0  1.000000e+02         1.000000e+02
# mean             2.0  1.644375e+07         1.196550e+07
# std              0.0  4.202164e+07         2.843751e+07
# min              2.0  6.500000e+05         7.000000e+05
# 25%              2.0  1.900000e+06         1.800000e+06
# 50%              2.0  3.999500e+06         3.800000e+06
# 75%              2.0  1.207500e+07         1.000000e+07
# max              2.0  2.860000e+08         2.500000e+08

# %%
dataLP2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
dataLP2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    52
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     45
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       3
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##คอนโด

# %%
open_dataC = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน update.xlsx',sheet_name=2)
open_dataC.head()
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0     3500000            3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1     1930000            2200000.0    50,000-90,000 บาท/ตารางเมตร
# 2     2438000            2800000.0    35,000-80,000 บาท/ตารางเมตร
# 3     1600000            2300000.0    30,000-80,000 บาท/ตารางเมตร
# 4     1860000            1800000.0    30,000-80,000 บาท/ตารางเมตร
#
#    เหตุผลไม่มั่นใจราคาประเมิน                    ให้คะแนนทรัพย์  Unnamed: 9  \
# ...

# %%
open_dataC['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
dataC_P1 = open_dataC[open_dataC['ID ผู้ประเมิน']==1]

# %% [markdown]
# ##ทาวน์โฮม

# %%
open_dataT = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน update.xlsx',sheet_name=3)
open_dataT.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2              1  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4              1  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     1045000             700000.0
# 1                        มั่นใจ     1045000            1500000.0
# 2                        มั่นใจ      935000             700000.0
# 3                        มั่นใจ      935000            1500000.0
# 4                        มั่นใจ     2520000            3500000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย  เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                         NaN
# ...

# %%
open_dataT['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    120
# 2    120
# Name: ID ผู้ประเมิน, dtype: int64

# %%
dataT_P1 = open_dataT[open_dataT['ID ผู้ประเมิน']==1]
dataT_P2 = open_dataT[open_dataT['ID ผู้ประเมิน']==2]

# %% [markdown]
# ##อาคารพาณิชย์

# %%
open_dataS = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน update.xlsx',sheet_name=4)
open_dataS.head()
# Out:
#    ID ผู้ประเมิน                             post id          property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2              1  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4              1  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ     6600000            6000000.0
# 1                        มั่นใจ     6600000            8000000.0
# 2                        มั่นใจ    11400000           12000000.0
# 3                        มั่นใจ    11400000           12000000.0
# 4                        มั่นใจ    22500000           13500000.0
#
#              ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# ...

# %%
open_dataS['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# 2    10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
dataS_P1 = open_dataS[open_dataS['ID ผู้ประเมิน']==1]
dataS_P2 = open_dataS[open_dataS['ID ผู้ประเมิน']==2]

# %% [markdown]
# #เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape #mape

# %%
from types import MethodType

# %% [markdown]
# ##MAPE บ้าน

# %%
dataH_P2['ประเมินโดย 1'] = dataH_P2['post id'].map(dataH_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
dataH_P2.head()
# Out:
# <ipython-input-147-9691b61f9c0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataH_P2['ประเมินโดย 1'] = dataH_P2['post id'].map(dataH_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataH_P2.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 2'}, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
MHP = dataH_P2[['post id','ราคาทรัพย์','ประเมินโดย 1','ประเมินโดย 2']]
MHP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0     2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0     2500000.0
# ..                                     ...         ...           ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0     4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0     1200000.0
#
#      ประเมินโดย 2
# 1       2700000.0
# 3       2400000.0
# 5       9000000.0
# 7       3700000.0
# 9       2500000.0
# ..            ...
# ...

# %%
#เช็ค missing
MHP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2     True
# dtype: bool

# %%
#แก้ missing
MHP = MHP.fillna(value={'ประเมินโดย 2':dataH_P2['ประเมินโดย 2'].mean()})
#ไม่ควรเติม mean หรือ 0 แต่ควรใช้เป็น เอาค่าที่เหลืออยู่มาสร้างโมเดลแล้วเอาค่าที่มีอยู่มาทำนายค่าที่หายไป

# %%
MHP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %%
ATH = MHP[['ราคาทรัพย์']]
PH1 = MHP[['ประเมินโดย 1']]
PH2 = MHP[['ประเมินโดย 2']]

# %%
MH1 = mape(ATH,PH1)
MH2 = mape(ATH,PH2)
MH12 = mape(PH1,PH2)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {MH1:.2f}\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {MH2:.2f}\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {MH12:.2f}')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 0.12
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 0.10
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 0.14

# %% [markdown]
# ##MAPE ที่ดิน

# %%
dataL_P2['ประเมินโดย 1'] = dataL_P2['post id'].map(dataL_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
dataL_P2.head()
# Out:
# <ipython-input-156-88a8cd396aaf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataL_P2['ประเมินโดย 1'] = dataL_P2['post id'].map(dataL_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataL_P2.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 2'}, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
MLP = dataL_P2[['post id','ราคาทรัพย์','ประเมินโดย 1','ประเมินโดย 2']]
MLP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000     1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000     8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000    18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000    35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000     2200000.0
# ..                                     ...         ...           ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000     4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000      500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000     2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000     1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000     2500000.0
#
#      ประเมินโดย 2
# 1       2000000.0
# 4      12000000.0
# 7      70000000.0
# 10     60000000.0
# 13      2500000.0
# ..            ...
# ...

# %%
MLP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %%
ATL = MLP[['ราคาทรัพย์']]
PL1 = MLP[['ประเมินโดย 1']]
PL2 = MLP[['ประเมินโดย 2']]

# %%
ML1 = mape(ATL,PL1)
ML2 = mape(ATL,PL2)
ML12 = mape(PL1,PL2)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {ML1:.2f}\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {ML2:.2f}\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {ML12:.2f}')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 0.41
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 0.40
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 0.74

# %% [markdown]
# ##MAPE คอนโด

# %%
dataC_P1.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 1'}, inplace=True)

# %%
MCP = dataC_P1[['post id','ราคาทรัพย์','ประเมินโดย 1']]
MCP
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย 1
# 0     32.0   3500000.0     3500000.0
# 1     36.0   1930000.0     2200000.0
# 2    603.0   2438000.0     2800000.0
# 3   1395.0   1600000.0     2300000.0
# 4   1443.0   1860000.0     1800000.0
# 5   1609.0   1490000.0     1500000.0
# 6   1640.0   1280000.0     1600000.0
# 7   1641.0   4290000.0     2700000.0
# 8   1650.0   1700000.0     1550000.0
# 9   1840.0   3790000.0     2800000.0

# %%
#เช็ค missing
MCP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# dtype: bool

# %%
#แก้ missing
#MCP = MCP.fillna(method='ffill') เติมค่าในคอลัมน์จากบนลงล่าง

# %% [markdown]
# ##MAPE ทาวน์โฮม

# %%
dataT_P2['ประเมินโดย 1'] = dataT_P2['post id'].map(dataT_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
dataT_P2.head()
# Out:
# <ipython-input-167-d50e52639d66>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataT_P2['ประเมินโดย 1'] = dataT_P2['post id'].map(dataT_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5              2  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7              2  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9              2  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataT_P2.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 2'}, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
MTP = dataT_P2[['post id','ราคาทรัพย์','ประเมินโดย 1','ประเมินโดย 2']]
MTP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0      700000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0     3500000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0     1000000.0
# ..                                     ...         ...           ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0     1000000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0     1500000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0     1600000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0     1600000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0     1700000.0
#
#      ประเมินโดย 2
# 1       1500000.0
# 3       1500000.0
# 5       4000000.0
# 7       3200000.0
# 9        800000.0
# ..            ...
# ...

# %%
#เช็ค missing
MTP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %%
ATT = MTP[['ราคาทรัพย์']]
PT1 = MTP[['ประเมินโดย 1']]
PT2 = MTP[['ประเมินโดย 2']]

# %%
MT1 = mape(ATT,PT1)
MT2 = mape(ATT,PT2)
MT12 = mape(PT1,PT2)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {MT1:.2f}\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {MT2:.2f}\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {MT12:.2f}')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 0.11
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 0.09
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 0.11

# %% [markdown]
# ##MAPE อาคารพาณิชย์

# %%
dataS_P2['ประเมินโดย 1'] = dataS_P2['post id'].map(dataS_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
dataS_P2.head()
# Out:
# <ipython-input-174-8c20e80bdce7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataS_P2['ประเมินโดย 1'] = dataS_P2['post id'].map(dataS_P1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                             post id          property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5              2  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7              2  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9              2  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
dataS_P2.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 2'}, inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
MSP = dataS_P2[['post id','ราคาทรัพย์','ประเมินโดย 1','ประเมินโดย 2']]
MSP
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
#
#     ประเมินโดย 2
# 1      8000000.0
# 3     12000000.0
# 5     20000000.0
# 7      4000000.0
# 9      3000000.0
# 11     4000000.0
# 13     2100000.0
# 15     5000000.0
# 17     8000000.0
# 19    10000000.0

# %%
#เช็ค missing
MSP.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %%
ATS = MSP[['ราคาทรัพย์']]
PS1 = MSP[['ประเมินโดย 1']]
PS2 = MSP[['ประเมินโดย 2']]

# %%
MSP1 = mape(ATS,PS1)
MSP2 = mape(ATS,PS2)
MSP12 = mape(PS1,PS2)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {MSP1:.2f}\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {MSP2:.2f}\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {MSP12:.2f}')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 0.18
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 0.12
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 0.22

# %% [markdown]
# ##วิธีของ อ

# %%
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# %%
#บ้าน
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.00%
# นักประเมิน คนที่ 2 = 8.52%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.60%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %%
#ที่ดิน
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %%
#คอนโด
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nคอนโด\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id1)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# คอนโด
# นักประเมิน คนที่ 1 = 18.36%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %%
#ทาวน์โฮม
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 16.21%
# นักประเมิน คนที่ 2 = 12.75%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %%
#อาคารพาณิชย์
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 19.28%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# # เพิ่มเติม

# %% [markdown]
# ##เขียน function ตรวจสอบค่าที่เติม 0 ผิด
# - 0 เกิน 0 ขาด
# - check (a,b) โดยการเลือก max จาก a,b แล้วเอาค่า max ตั้ง เอาอีกตัวหาร
# - a คือ ราคาประเมิน b คือ ราคาทรัพย์

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %%
check_v(100,1200)
# Out:
# 12.0

# %% [markdown]
# ##สร้าง column ใหม่ ลงในตาราง home(บ้าน) โดยค่า column ค่าจาก function check (ราคาตั้งขาย, ราคาประเมิน 1)

# %% [markdown]
# # HW 2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# ##Load ตารางจาก google sheet

# %% [markdown]
# Error :
# * 'ascil' codec สันนิษฐานไว้ก่อนว่าน่าจะเพราะภาษาไทย ให้แก้ชื่อไฟล์ ฟ้อนต์
# หรือชื่อชีทให้เป็นภาษาอังกฤษ
# * เวลา copy link มาจากเน็ต ให้ดูสี ถ้าเป็นสีดำใช้ไม่ได้ ดูลูกน้ำดีๆ ทำให้เป็นสีแดง

# %% [markdown]
# ##บ้าน

# %%
MHP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0     2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0     2500000.0
# ..                                     ...         ...           ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0     4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0     1200000.0
#
#      ประเมินโดย 2
# 1       2700000.0
# 3       2400000.0
# 5       9000000.0
# 7       3700000.0
# 9       2500000.0
# ..            ...
# ...

# %%
MHP['check1'] = MHP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
MHP['check2'] = MHP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
MHP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0     2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0     2500000.0
# ..                                     ...         ...           ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0     4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0     1200000.0
#
#      ประเมินโดย 2    check1    check2
# 1       2700000.0  1.080000  1.000000
# 3       2400000.0  1.181818  1.083333
# ...

# %%
check1 = list()
for row in MHP.iterrows():
    check1.append(check_v(row[1]['ราคาทรัพย์'],row[1]['ประเมินโดย 1']))
check1
# Out:
# [1.08,
#  1.1818181818181819,
#  1.18,
#  1.2571428571428571,
#  1.1,
#  1.271111111111111,
#  1.36,
#  1.0153846153846153,
#  1.3684,
#  1.031941031941032,
#  1.0476190476190477,
#  1.1785714285714286,
#  1.0592592592592593,
#  1.188,
#  1.1275,
#  1.1,
#  1.1157142857142857,
#  1.0371428571428571,
#  1.0588235294117647,
#  1.2571428571428571,
#  1.13125,
#  1.0,
#  1.0888888888888888,
#  1.0892333472978635,
#  1.0444444444444445,
#  1.0,
#  1.0434782608695652,
#  1.02,
#  1.25,
#  1.13,
#  1.0714285714285714,
#  1.0,
#  1.0,
#  1.3833333333333333,
#  1.03125,
#  1.1611111111111112,
#  1.0526315789473684,
#  1.5384615384615385,
#  1.0227272727272727,
#  1.1363636363636365,
#  1.1111111111111112,
#  1.1290322580645162,
#  1.1388888888888888,
#  1.0,
#  1.0933333333333333,
#  1.3093125,
#  1.21,
#  1.24,
#  1.1642857142857144,
#  1.1,
#  1.4685314685314685,
#  1.1111111111111112,
#  1.1942857142857144,
#  1.0714285714285714,
#  1.0710526315789475,
#  1.4575,
#  1.046,
#  1.09375,
# ...

# %%
MHP.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0      600000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0     3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0     4200000.0
# ..                                     ...         ...           ...
# 43    https://nayoo.co/khonkaen/posts/1128   4200000.0     4200000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0     1200000.0
# 65    https://nayoo.co/khonkaen/posts/2143   5200000.0     5200000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0     3500000.0
#
#      ประเมินโดย 2    check1    check2
# 187     2500000.0  1.800000  1.250000
# 75      1300000.0  1.538462  3.333333
# ...

# %%
MHP.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0      600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0     2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0     3500000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# ..                                     ...         ...           ...
# 169  https://nayoo.co/khonkaen/posts/11264   6500000.0     5600000.0
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0     3300000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0     1500000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0     1700000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
#
#      ประเมินโดย 2    check1    check2
# 75      1300000.0  1.538462  3.333333
# 5       9000000.0  1.180000  1.525424
# ...

# %% [markdown]
# ##ที่ดิน

# %%
MLP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000     1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000     8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000    18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000    35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000     2200000.0
# ..                                     ...         ...           ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000     4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000      500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000     2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000     1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000     2500000.0
#
#      ประเมินโดย 2
# 1       2000000.0
# 4      12000000.0
# 7      70000000.0
# 10     60000000.0
# 13      2500000.0
# ..            ...
# ...

# %%
MLP['check1'] = MLP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
MLP['check2'] = MLP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
MLP
# Out:
# <ipython-input-197-ed5a4535b7ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLP['check1'] = MLP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# <ipython-input-197-ed5a4535b7ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MLP['check2'] = MLP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000     1800000.0
# ...

# %%
MLP.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000     4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000    32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   160000000    14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000    24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000    18000000.0
# ..                                     ...         ...           ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000     4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000     1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000     1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000      650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000     2500000.0
#
#      ประเมินโดย 2     check1     check2
# 194    75000000.0  20.000000   1.200000
# 112     2000000.0  12.307692   1.300000
# ...

# %%
MLP.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 58    https://nayoo.co/khonkaen/posts/9203   160000000    14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000    24000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550     6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000     2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000     1600000.0
# ..                                     ...         ...           ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000     2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000    10000000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000     2800000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000      500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000    12000000.0
#
#      ประเมินโดย 2     check1     check2
# 58     11000000.0  11.428571  14.545455
# 47     18000000.0  10.208333  13.611111
# ...

# %% [markdown]
# ##คอนโด

# %%
MCP
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย 1
# 0     32.0   3500000.0     3500000.0
# 1     36.0   1930000.0     2200000.0
# 2    603.0   2438000.0     2800000.0
# 3   1395.0   1600000.0     2300000.0
# 4   1443.0   1860000.0     1800000.0
# 5   1609.0   1490000.0     1500000.0
# 6   1640.0   1280000.0     1600000.0
# 7   1641.0   4290000.0     2700000.0
# 8   1650.0   1700000.0     1550000.0
# 9   1840.0   3790000.0     2800000.0

# %%
MCP['check1'] = MCP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
MCP
# Out:
# <ipython-input-201-7c5a2ef95013>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MCP['check1'] = MCP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
#    post id  ราคาทรัพย์  ประเมินโดย 1    check1
# 0     32.0   3500000.0     3500000.0  1.000000
# 1     36.0   1930000.0     2200000.0  1.139896
# 2    603.0   2438000.0     2800000.0  1.148482
# 3   1395.0   1600000.0     2300000.0  1.437500
# 4   1443.0   1860000.0     1800000.0  1.033333
# 5   1609.0   1490000.0     1500000.0  1.006711
# 6   1640.0   1280000.0     1600000.0  1.250000
# 7   1641.0   4290000.0     2700000.0  1.588889
# 8   1650.0   1700000.0     1550000.0  1.096774
# 9   1840.0   3790000.0     2800000.0  1.353571

# %%
MCP.sort_values(by=['check1'],ascending=False)
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย 1    check1
# 7   1641.0   4290000.0     2700000.0  1.588889
# 3   1395.0   1600000.0     2300000.0  1.437500
# 9   1840.0   3790000.0     2800000.0  1.353571
# 6   1640.0   1280000.0     1600000.0  1.250000
# 2    603.0   2438000.0     2800000.0  1.148482
# 1     36.0   1930000.0     2200000.0  1.139896
# 8   1650.0   1700000.0     1550000.0  1.096774
# 4   1443.0   1860000.0     1800000.0  1.033333
# 5   1609.0   1490000.0     1500000.0  1.006711
# 0     32.0   3500000.0     3500000.0  1.000000

# %% [markdown]
# ##ทาวน์โฮม

# %%
MTP
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0      700000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0     3500000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0     1000000.0
# ..                                     ...         ...           ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0     1000000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0     1500000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0     1600000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0     1600000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0     1700000.0
#
#      ประเมินโดย 2
# 1       1500000.0
# 3       1500000.0
# 5       4000000.0
# 7       3200000.0
# 9        800000.0
# ..            ...
# ...

# %%
MTP['check1'] = MTP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
MTP['check2'] = MTP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
MTP
# Out:
# <ipython-input-204-d56861d61847>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MTP['check1'] = MTP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# <ipython-input-204-d56861d61847>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MTP['check2'] = MTP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# ...

# %%
MTP.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0      350000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0     1500000.0
# 132    https://nayoo.co/khonkaen/posts/619   1430000.0      950000.0
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# 174   https://nayoo.co/khonkaen/posts/3478   2190000.0     1500000.0
# ..                                     ...         ...           ...
# 228  https://nayoo.co/khonkaen/posts/17923   1990000.0     2000000.0
# 167   https://nayoo.co/khonkaen/posts/2829   2490000.0     2500000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0     2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411   3200000.0     3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503   1500000.0     1500000.0
#
#      ประเมินโดย 2    check1    check2
# 176      400000.0  6.257143  5.475000
# 180     1500000.0  1.613333  1.613333
# ...

# %%
MTP.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0      350000.0
# 234  https://nayoo.co/khonkaen/posts/18090   3000000.0     2800000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0     1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0      700000.0
# 225  https://nayoo.co/khonkaen/posts/17742   2500000.0     2200000.0
# ..                                     ...         ...           ...
# 188   https://nayoo.co/khonkaen/posts/8101   3200000.0     3300000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0     2800000.0
# 199  https://nayoo.co/khonkaen/posts/12957   1500000.0     1600000.0
# 151   https://nayoo.co/khonkaen/posts/1978   2500000.0     2700000.0
# 181   https://nayoo.co/khonkaen/posts/6104   2200000.0     2500000.0
#
#      ประเมินโดย 2    check1    check2
# 176      400000.0  6.257143  5.475000
# 234     1500000.0  1.071429  2.000000
# ...

# %% [markdown]
# ##อาคารพาณิชย์

# %%
MSP['check1'] = MSP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
MSP['check2'] = MSP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
MSP
# Out:
# <ipython-input-207-d21e10bc6c10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MSP['check1'] = MSP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# <ipython-input-207-d21e10bc6c10>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MSP['check2'] = MSP.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# ...

# %%
MSP.sort_values(by=['check1'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
#
#     ประเมินโดย 2    check1    check2
# 9      3000000.0  1.772727  1.300000
# 5     20000000.0  1.666667  1.125000
# 11     4000000.0  1.333333  1.200000
# 15     5000000.0  1.315789  1.000000
# 1      8000000.0  1.166667  1.142857
# ...

# %%
MSP.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
#
#     ประเมินโดย 2    check1    check2
# 9      3000000.0  1.772727  1.300000
# 11     4000000.0  1.333333  1.200000
# 1      8000000.0  1.166667  1.142857
# 7      4000000.0  1.142857  1.142857
# 13     2100000.0  1.041667  1.142857
# ...

# %% [markdown]
# #MAPE หลังจากแก้ใน excel

# %%
#บ้าน
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน แก้แล้ว.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.75%
# นักประเมิน คนที่ 2 = 9.51%
# ความผิดพลาดระหว่างนักประเมินทั้ง 13.54%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์

# %%
#ที่ดิน
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน แก้แล้ว.xlsx',sheet_name='ที่ดิน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 53.94%
# นักประเมิน คนที่ 2 = 25.89%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.21%
# จำนวนทรัพย์ทั้งหมด 40 ทรัพย์

# %%
#คอนโด
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน แก้แล้ว.xlsx',sheet_name='คอนโด')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nคอนโด\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id1)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# คอนโด
# นักประเมิน คนที่ 1 = 18.36%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %%
#ทาวน์โฮม
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน แก้แล้ว.xlsx',sheet_name='ทาวน์โฮม')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nทาวน์โฮม\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ทาวน์โฮม
# นักประเมิน คนที่ 1 = 20.12%
# นักประเมิน คนที่ 2 = 15.84%
# ความผิดพลาดระหว่างนักประเมินทั้ง 11.66%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์

# %%
#อาคารพาณิชย์
temp = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน แก้แล้ว.xlsx',sheet_name='อาคารพาณิชย์')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = MAPE(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = MAPE(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมินโดย 2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมินโดย 2','ราคาทรัพย์'])
one2two = MAPE(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมินโดย 2'])
two2one = MAPE(id2_d['ประเมินโดย 2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# อาคารพาณิชย์
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 19.28%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# # HW 3 Visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์
