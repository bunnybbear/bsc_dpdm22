# %% [markdown]
# <a href="https://colab.research.google.com/github/bunnybbear/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
open_data1 = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx')

# %%
open_data1.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %%
all_P = set(list(open_data1['ID ผู้ประเมิน']))
all_P
# Out:
# {1, 2}

# %%
open_P1 = open_data1[open_data1['ID ผู้ประเมิน']==1]
open_P1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
open_P2 = open_data1[open_data1['ID ผู้ประเมิน']==2]
open_P2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #พิจารณาผู้ประเมินคนที่ 1

# %%
dataP1 = open_P1[['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataP1.head()
# Out:
#    ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0              1                        มั่นใจ            2500000.0
# 2              1                        มั่นใจ            2200000.0
# 4              1                        มั่นใจ            5000000.0
# 6              1                        มั่นใจ            3500000.0
# 8              1                        มั่นใจ            2500000.0
#
#                        ให้คะแนนทรัพย์
# 0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 2  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 4   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 6  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 8   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataP1.describe()
# Out:
#        ID ผู้ประเมิน  ประเมินราคาซื้อ-ขาย
# count          100.0         1.000000e+02
# mean             1.0         3.938500e+06
# std              0.0         2.368553e+06
# min              1.0         6.000000e+05
# 25%              1.0         2.775000e+06
# 50%              1.0         3.600000e+06
# 75%              1.0         4.500000e+06
# max              1.0         1.600000e+07

# %%
dataP1E = dataP1['ความมั่นใจในการเมินราคาทรัพย์']
dataP1E
# Out:
# 0      มั่นใจ
# 2      มั่นใจ
# 4      มั่นใจ
# 6      มั่นใจ
# 8      มั่นใจ
#         ...
# 155    มั่นใจ
# 156    มั่นใจ
# 157    มั่นใจ
# 158    มั่นใจ
# 159    มั่นใจ
# Name: ความมั่นใจในการเมินราคาทรัพย์, Length: 100, dtype: object

# %%
dataP1E = dataP1[dataP1['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
dataP1E
# Out:
# ID ผู้ประเมิน                    100
# ความมั่นใจในการเมินราคาทรัพย์    100
# ประเมินราคาซื้อ-ขาย              100
# ให้คะแนนทรัพย์                   100
# dtype: int64

# %%
#จากคำสั่ง dataP1.describe มีจำนวนข้อมูลอยู่ 100 และจาก dataP1E ผู้ประเมินคนที่ 1 ได้รับความมั่นใจ 100
PC1 = (100/100)*100;
PC1
# Out:
# 100.0

# %%
dataP1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# #พิจารณาผู้ประเมินคนที่ 2

# %%
dataP2 = open_P2[['ID ผู้ประเมิน','ความมั่นใจในการเมินราคาทรัพย์','ประเมินราคาซื้อ-ขาย','ให้คะแนนทรัพย์']]
dataP2.head()
# Out:
#    ID ผู้ประเมิน ความมั่นใจในการเมินราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1              2                        มั่นใจ            2700000.0
# 3              2                        มั่นใจ            2400000.0
# 5              2                        มั่นใจ            9000000.0
# 7              2                        มั่นใจ            3700000.0
# 9              2                        มั่นใจ            2500000.0
#
#                       ให้คะแนนทรัพย์
# 1   4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 5  5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน
# 7  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# 9  3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน

# %%
dataP2.describe()
# Out:
#        ID ผู้ประเมิน  ประเมินราคาซื้อ-ขาย
# count           90.0         8.900000e+01
# mean             2.0         4.153258e+06
# std              0.0         2.386901e+06
# min              2.0         9.900000e+05
# 25%              2.0         2.600000e+06
# 50%              2.0         3.900000e+06
# 75%              2.0         4.900000e+06
# max              2.0         1.700000e+07

# %%
dataP2E = dataP2[dataP2['ความมั่นใจในการเมินราคาทรัพย์']=='มั่นใจ'].count()
dataP2E
# Out:
# ID ผู้ประเมิน                    89
# ความมั่นใจในการเมินราคาทรัพย์    89
# ประเมินราคาซื้อ-ขาย              89
# ให้คะแนนทรัพย์                   89
# dtype: int64

# %%
#จากคำสั่ง dataP2.describe มีจำนวนข้อมูลอยู่ 90 และจาก dataP2E ผู้ประเมินคนที่ 2 ได้รับความมั่นใจ 89
PC2 = (89/90)*100;
PC2
# Out:
# 98.88888888888889

# %%
#อีกวิธี
dataP2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
dataP2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# #เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
SCP1 = open_P1[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย']]
SCP1
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# 0       https://nayoo.co/khonkaen/posts/25   2700000.0            2500000.0
# 2       https://nayoo.co/khonkaen/posts/33   2600000.0            2200000.0
# 4      https://nayoo.co/khonkaen/posts/495   5900000.0            5000000.0
# 6      https://nayoo.co/khonkaen/posts/564   4400000.0            3500000.0
# 8      https://nayoo.co/khonkaen/posts/566   2750000.0            2500000.0
# ..                                     ...         ...                  ...
# 155  https://nayoo.co/khonkaen/posts/19495   5500000.0            4500000.0
# 156  https://nayoo.co/khonkaen/posts/19496   7911000.0            5200000.0
# 157     https://nayoo.co/khonkaen/posts/20   2000000.0            3600000.0
# 158     https://nayoo.co/khonkaen/posts/31   4000000.0            4000000.0
# 159    https://nayoo.co/khonkaen/posts/570   1375000.0            1200000.0
#
# [100 rows x 3 columns]

# %%
SCP2 = open_P2[['post id','ราคาทรัพย์','ประเมินราคาซื้อ-ขาย']]
SCP2
# Out:
#                                    post id  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0            2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0            2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0            9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0            3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0            2500000.0
# ..                                     ...         ...                  ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0            5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0            7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0            2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0            3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0            1400000.0
#
# [90 rows x 3 columns]

# %%
SCP12 = SCP2.merge(SCP1, left_on='post id', right_on='post id')
SCP12
# Out:
#                                   post id  ราคาทรัพย์_x  \
# 0      https://nayoo.co/khonkaen/posts/25     2700000.0
# 1      https://nayoo.co/khonkaen/posts/33     2600000.0
# 2     https://nayoo.co/khonkaen/posts/495     5900000.0
# 3     https://nayoo.co/khonkaen/posts/564     4400000.0
# 4     https://nayoo.co/khonkaen/posts/566     2750000.0
# ..                                    ...           ...
# 85  https://nayoo.co/khonkaen/posts/19495     5500000.0
# 86  https://nayoo.co/khonkaen/posts/19496     7911000.0
# 87     https://nayoo.co/khonkaen/posts/20     2000000.0
# 88     https://nayoo.co/khonkaen/posts/31     4000000.0
# 89    https://nayoo.co/khonkaen/posts/570     1375000.0
#
#     ประเมินราคาซื้อ-ขาย_x  ราคาทรัพย์_y  ประเมินราคาซื้อ-ขาย_y
# 0               2700000.0     2700000.0              2500000.0
# 1               2400000.0     2600000.0              2200000.0
# 2               9000000.0     5900000.0              5000000.0
# ...
